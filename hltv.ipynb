# %% [markdown]
# <a href="https://colab.research.google.com/github/ducndh/cs320MachineLearningProjects/blob/main/hltv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cloudscraper
# Out:
# Collecting cloudscraper
#   Downloading https://files.pythonhosted.org/packages/83/e4/f1d3872ce822f52f4133cc04960185f64676ca5ec87f05a5350fc0c0a92f/cloudscraper-1.2.48-py2.py3-none-any.whl (94kB)
#      |████████████████████████████████| 102kB 6.9MB/s
# Collecting requests-toolbelt>=0.9.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 6.8MB/s
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.6/dist-packages (from cloudscraper) (2.4.7)
# Requirement already satisfied: requests>=2.9.2 in /usr/local/lib/python3.6/dist-packages (from cloudscraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.2->cloudscraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.2->cloudscraper) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.2->cloudscraper) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.2->cloudscraper) (2.10)
# Installing collected packages: requests-toolbelt, cloudscraper
# Successfully installed cloudscraper-1.2.48 requests-toolbelt-0.9.1

# %%
import requests
import urllib
import datetime
import cloudscraper
from bs4 import BeautifulSoup
from re import sub
import re
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
from datetime import datetime
import time
from requests.auth import HTTPProxyAuth
import random


PREFIX = 'https://www.hltv.org'
proxyDict = None
proxyAuth = None

# %%
def get_parsed_page(url, proxy_=None, auth_=None):
    TIMESLEEP = random.uniform(0.25, 0.3)
    time.sleep(TIMESLEEP)
    scraper = cloudscraper.create_scraper()
    html = scraper.get(url).content
    soup = BeautifulSoup(html, 'html.parser')
    return(soup)

# %%
# download all urls matches
def get_results_url(filename=None):
    all_matches = []
    for i in range(200):
        if i == 0:
            results = get_parsed_page('http://www.hltv.org/results')
        else:
            results = get_parsed_page(f'http://www.hltv.org/results?offset={i}00')
        # list of matches
        all_matches += [url_.find('a', {"class": "a-reset"})['href'] for url_ in
                        results.find('div',
                                     {"class": "results-all", 'data-zonedgrouping-group-classes': "results-sublist"}).
                        find_all('div', {"class": "result-con"})]
    all_matches = np.array(all_matches)
    data = pd.DataFrame(all_matches, columns=['match_url'])
    data.index.name = 'id'
    if filename is None:
        return data
    else:
        data.to_csv(f'{filename}.csv')
        return data

df = get_results_url(filename='data_all_matches').iloc[:20000]
df
# Out:
#                                                match_url
# id
# 0      /matches/2345354/agf-vs-ldlc-esea-advanced-sea...
# 1      /matches/2345362/nexus-vs-singularity-cyberbet...
# 2      /matches/2345193/astralis-vs-ence-iem-beijing-...
# 3             /matches/2345299/forze-vs-big-flashpoint-2
# 4      /matches/2345361/lilmix-vs-giants-cyberbet-gol...
# ...                                                  ...
# 19995  /matches/2324700/chaos-vs-singularity-esea-mdl...
# 19996  /matches/2324420/kinguin-vs-movistar-riders-es...
# 19997  /matches/2324456/valiance-vs-red-reserve-esea-...
# 19998  /matches/2324665/forze-vs-avangar-cis-minor-fa...
# 19999  /matches/2324750/bpro-vs-vexed-streamme-gauntl...
#
# [20000 rows x 1 columns]

# %%
class MatchPageParams:
    def __init__(self, df, start_index=None, finish_index=None):
        self.df = df
        self.MATCH_PAGE = None
        self.MATCH_ID = None
        self.match = None
        self.start_index = start_index
        self.finish_index = finish_index

    def add_all_params(self):
        time_start = time.time()
        for match in self.df['match_url'][self.start_index:self.finish_index]:
            self.MATCH_ID = list(self.df['match_url']).index(match)
            print('match id -', self.MATCH_ID, '; time spent -', time.time() - time_start)
            self.MATCH_PAGE = get_parsed_page(PREFIX + match)
            self.add_url_teams()
            self.add_10_urls_players()
            self.add_maps()
            self.add_date()
            self.add_scores()
            self.add_history()
            self.add_ranks()
            self.add_5last_urls_opponents()
            self.add_5last_scores_and_types()

    def _get_score_(self):
        score = self.MATCH_PAGE.find('div', {'class': 'match-page'}).\
                find('div', {'class': 'teamsBox'}).\
                find_all('div', {'class': 'team'})
        for i in range(len(score)):
            score[i] = score[i].find('div', {'class': f'team{i + 1}-gradient'}).\
                                find_all('div')[-1].text
            self.df[f'score{i + 1}'][self.MATCH_ID] = score[i]

    def add_scores(self):
        # add columns
        if 'score1' not in self.df.columns:
            self.df['score1'] = ""
        if 'score2' not in self.df.columns:
            self.df['score2'] = ""
        if self.df['score1'][self.MATCH_ID] == "" or self.df['score2'][self.MATCH_ID] == "":
            self._get_score_()

    def _get_total_maps_(self):
        try:
            table = self.MATCH_PAGE.find('div', {'class': 'flexbox-column'}).\
                    find_all('div', {'class': 'mapholder'})
            self.df['total_maps'][self.MATCH_ID] = len(table)
            self.df['maps_played'][self.MATCH_ID] = 0
            for i in table:
                played = i.find('div', {'class': 'results'}).find('div', {'class': 'results-center'})
                if played.text:
                    self.df['maps_played'][self.MATCH_ID] += 1
        except:
            self.df['total_maps'][self.MATCH_ID] = 0
            self.df['maps_played'][self.MATCH_ID] = 0
            

    def add_total_maps(self):
        # add columns
        if 'total_maps' not in self.df:
            self.df['total_maps'] = ""
        if 'maps_played' not in self.df:
            self.df['maps_played'] = ""
        if self.df['total_maps'][self.MATCH_ID] == "" or self.df['maps_played'][self.MATCH_ID] == "":
            self._get_total_maps_()

    def _get_ranks_(self):
        ranks = self.MATCH_PAGE.find('div', {'class': 'lineups'}).\
                find_all('div', {'class': 'box-headline'})
        for i in range(len(ranks)):
            ranks[i] = ranks[i].find('div', {'class': 'teamRanking'}).text
            self.df[f'rank{i + 1}'][self.MATCH_ID] = ranks[i]
            
    def add_ranks(self):
        # add columns
        if 'rank1' not in self.df:
            self.df['rank1'] = ""
        if 'rank2' not in self.df:
            self.df['rank2'] = ""
        if self.df['rank1'][self.MATCH_ID] == "" or self.df['rank2'][self.MATCH_ID] == "":
            self._get_ranks_()
    
    def _get_date_(self):
        self.df['date'][self.MATCH_ID] = datetime.utcfromtimestamp(int(
                self.MATCH_PAGE.find('div', {'class': 'timeAndEvent'}).
                find('div', {'class': 'time'})['data-unix'][:-3])).strftime('%Y-%m-%d')
    
    def add_date(self):
        if 'date' not in self.df:
            self.df['date'] = ""
        if self.df['date'][self.MATCH_ID] == "":
            self._get_date_()

    def _get_history_(self):
        h2h = self.MATCH_PAGE.find('div', {'class': 'head-to-head'}).\
                find_all('div', {'class': 'flexbox-column'})
        self.df['h2h_wins1'][self.MATCH_ID] = h2h[0].find('div', {'class': 'bold'}).text
        self.df['h2h_wins2'][self.MATCH_ID] = h2h[-1].find('div', {'class': 'bold'}).text

    def add_history(self):
        if 'h2h_wins1' not in self.df:
            self.df['h2h_wins1'] = ""
        if 'h2h_wins2' not in self.df:
            self.df['h2h_wins2'] = ""
        if self.df['h2h_wins1'][self.MATCH_ID] == "" or self.df['h2h_wins2'][self.MATCH_ID] == "":
            self._get_history_()

    def _get_5last_score_type_(self, team_id, match_id):
        try:
            tmp = self.MATCH_PAGE.find('div', {'class': 'past-matches'}).\
                    find_all('div', {'class': 'half-width'})[team_id].find('table', {'class': 'matches'}).\
                    find_all('tr', {'class': 'table'})[match_id]
            total = tmp.find('a', {'data-link-tracking-page': 'Matchpage'}).text
            self.df[f'5last_match{match_id + 1}_total_maps{team_id + 1}'][self.MATCH_ID] = total
            score = tmp.find('td', {'class': 'result'}).text.split(' - ')
            if int(score[0]) > int(score[1]):
                score = [1, 0]
            else:
                score = [0, 1]
            self.df[f'5last_match{match_id + 1}_score{team_id + 1}'][self.MATCH_ID] = score[0]
            self.df[f'5last_match{match_id + 1}_opponent_score{team_id + 1}'][self.MATCH_ID] = score[1]
        except:
            self.df[f'5last_match{match_id + 1}_total_maps{team_id + 1}'][self.MATCH_ID] = 0
            self.df[f'5last_match{match_id + 1}_score{team_id + 1}'][self.MATCH_ID] = 0
            self.df[f'5last_match{match_id + 1}_opponent_score{team_id + 1}'][self.MATCH_ID] = 0
        
    
    def add_5last_scores_and_types(self):
        for team_id in range(2):
            for match_id in range(5):
                if f'5last_match{match_id + 1}_total_maps{team_id + 1}' not in self.df:
                    self.df[f'5last_match{match_id + 1}_total_maps{team_id + 1}'] = ""
                if f'5last_match{match_id + 1}_score{team_id + 1}' not in self.df:
                    self.df[f'5last_match{match_id + 1}_score{team_id + 1}'] = ""
                if f'5last_match{match_id + 1}_opponent_score{team_id + 1}' not in self.df:
                    self.df[f'5last_match{match_id + 1}_opponent_score{team_id + 1}'] = ""
                if self.df[f'5last_match{match_id + 1}_total_maps{team_id + 1}'][self.MATCH_ID] == "" or\
                    self.df[f'5last_match{match_id + 1}_score{team_id + 1}'][self.MATCH_ID] == "" or\
                    self.df[f'5last_match{match_id + 1}_opponent_score{team_id + 1}'][self.MATCH_ID] == "":
                    self._get_5last_score_type_(team_id, match_id)

    def _get_5last_opponents_(self, team_id):
        arr = []
        tmp = self.MATCH_PAGE.find('div', {'class': 'past-matches'}).\
                find_all('div', {'class': 'half-width'})[team_id].find('table', {'class': 'matches'}).\
                find_all('tr', {'class': 'table'})
        for i in tmp:
            arr += [i.find('td', {'class': 'opponent'}).find('a')['href']]
        self.df[f'opponents_url_history_team{team_id + 1}'][self.MATCH_ID] = arr
        
    
    def add_5last_urls_opponents(self):
        for team_id in range(2):
            if f'opponents_url_history_team{team_id + 1}' not in self.df:
                self.df[f'opponents_url_history_team{team_id + 1}'] = ""
            if self.df[f'opponents_url_history_team{team_id + 1}'][self.MATCH_ID] == "":
                self._get_5last_opponents_(team_id)

    def _get_players_url__(self, team_id):
        arr = []
        tmp = self.MATCH_PAGE.find('div', {'class': 'lineups'}).\
                find_all('div', {'class': 'lineup'})[team_id].find('div', {'class': 'players'}).\
                find_all('td', {'class': 'player'})
        for i in tmp:
            try:
                arr += [i.find('a')['href']]
            except:
                arr += [""]
        self.df[f'players_url_{team_id + 1}'][self.MATCH_ID] = arr[:5]
        #print(arr)

    def add_10_urls_players(self):
        for team_id in range(2):
            if f'players_url_{team_id + 1}' not in self.df:
                self.df[f'players_url_{team_id + 1}'] = ""
            if self.df[f'players_url_{team_id + 1}'][self.MATCH_ID] == "":
                self._get_players_url__(team_id)

    def _get_event_url_(self):
        self.df['event_url'][self.MATCH_ID] = self.MATCH_PAGE.find('div', {'class': 'timeAndEvent'}).\
                find('div', {'class': 'event'}).find('a')['href']
    
    def add_url_event(self):
        if 'event_url' not in self.df:
            self.df['event_url'] = ""
        if self.df['event_url'][self.MATCH_ID] == "":
            self._get_event_url_()
    
    def _get_maps_(self):
        arr = []
        map_name = []
        score_maps1 = []
        score_maps2 = []
        picks = []
        try:
            tmp = self.MATCH_PAGE.find('div', {'class': 'flexbox-column'}).\
                    find_all('div', {'class': 'mapholder'})
            for i in tmp:
                played = i.find('div', {'class': 'results'}).find('div', {'class': 'results-center'})
                if played.text:
                    arr += [played.find('a')['href']]
                    map_name += [i.find('div', {'class': 'map-name-holder'}).find('div', {'class': 'mapname'}).text]
                    table = i.find('div', {'class': 'results-left'})
                    if self.df['total_maps'][self.MATCH_ID] > 1:
                        if table['class'][-1] == 'pick':
                            picks += [1]
                    score_maps1 += [table.find('div', {'class': 'results-team-score'}).text]
                    table = i.find('span', {'class': 'results-right'})
                    if self.df['total_maps'][self.MATCH_ID] > 1:
                        if table['class'][-1] == 'pick':
                            picks += [-1]
                    score_maps2 += [table.find('div', {'class': 'results-team-score'}).text]
            self.df['maps_url'][self.MATCH_ID] = arr
            self.df['maps_name'][self.MATCH_ID] = map_name
            self.df['score1_maps'][self.MATCH_ID] = score_maps1
            self.df['score2_maps'][self.MATCH_ID] = score_maps2
            if not picks:
                self.df['picks'][self.MATCH_ID] = "None"
            else:
                self.df['picks'][self.MATCH_ID] = picks
        except Exception as e:
            print(e)
            self.df['maps_url'][self.MATCH_ID] = "None"
            self.df['maps_name'][self.MATCH_ID] = "None"
            self.df['score1_maps'][self.MATCH_ID] = "None"
            self.df['score2_maps'][self.MATCH_ID] = "None"
            self.df['picks'][self.MATCH_ID] = "None"
    
    def add_maps(self):
        if 'maps_url' not in self.df:
            self.df['maps_url'] = ""
        if 'maps_name' not in self.df:
            self.df['maps_name'] = ""
        if 'score1_maps' not in self.df:
            self.df['score1_maps'] = ""
        if 'score2_maps' not in self.df:
            self.df['score2_maps'] = ""
        if 'picks' not in self.df:
            self.df['picks'] = ""
        if self.df['maps_url'][self.MATCH_ID] == "" or self.df['maps_name'][self.MATCH_ID] == "" or\
                self.df['score1_maps'][self.MATCH_ID] == "" or self.df['score2_maps'][self.MATCH_ID] == "" or\
                self.df['picks'][self.MATCH_ID] == "":
            self._get_maps_()
    
    def _get_url_teams_(self):
        tmp = self.MATCH_PAGE.find('div', {'class': 'teamsBox'}).\
                find_all('div', {'class': 'team'})
        self.df['url_team1'][self.MATCH_ID] = tmp[0].find('a')['href']
        self.df['url_team2'][self.MATCH_ID] = tmp[1].find('a')['href']
    
    def add_url_teams(self):
        if 'url_team1' not in self.df:
            self.df['url_team1'] = ""
        if 'url_team2' not in self.df:
            self.df['url_team2'] = ""
        if self.df['url_team1'][self.MATCH_ID] == "" or self.df['url_team2'][self.MATCH_ID] == "":
            self._get_url_teams_()


MatchPageParams(df).add_all_params()
# Out:
# match id - 0 ; time spent - 0.0025167465209960938
# 'total_maps'
# match id - 1 ; time spent - 1.188286542892456
# 'total_maps'
# match id - 2 ; time spent - 2.3637399673461914
# 'total_maps'
# match id - 3 ; time spent - 5.681586027145386
# 'total_maps'
# match id - 4 ; time spent - 7.236474514007568
# 'total_maps'
# match id - 5 ; time spent - 8.568827629089355
# 'total_maps'
# match id - 6 ; time spent - 9.613219261169434
# 'total_maps'
# match id - 7 ; time spent - 11.141970157623291
# 'total_maps'
# match id - 8 ; time spent - 14.30770492553711
# 'total_maps'
# match id - 9 ; time spent - 15.483323097229004
# 'total_maps'
# match id - 10 ; time spent - 16.528160333633423
# 'total_maps'
# match id - 11 ; time spent - 17.689842224121094
# 'total_maps'
# match id - 12 ; time spent - 18.7756609916687
# 'total_maps'
# match id - 13 ; time spent - 19.79660129547119
# 'total_maps'
# match id - 14 ; time spent - 21.59523844718933
# 'total_maps'
# match id - 15 ; time spent - 22.777008295059204
# 'total_maps'
# match id - 16 ; time spent - 23.855302333831787
# 'total_maps'
# match id - 17 ; time spent - 25.085461854934692
# 'total_maps'
# match id - 18 ; time spent - 26.8867609500885
# 'total_maps'
# match id - 19 ; time spent - 27.929975748062134
# 'total_maps'
# match id - 20 ; time spent - 29.558857202529907
# 'total_maps'
# match id - 21 ; time spent - 30.714752435684204
# 'total_maps'
# match id - 22 ; time spent - 31.90101385116577
# 'total_maps'
# match id - 23 ; time spent - 33.06030893325806
# 'total_maps'
# match id - 24 ; time spent - 34.37464261054993
# 'total_maps'
# match id - 25 ; time spent - 36.45554327964783
# 'total_maps'
# match id - 26 ; time spent - 37.7325656414032
# 'total_maps'
# match id - 27 ; time spent - 39.54932689666748
# 'total_maps'
# match id - 28 ; time spent - 40.62072682380676
# 'total_maps'
# match id - 29 ; time spent - 42.00613975524902
# 'total_maps'
# match id - 30 ; time spent - 43.77273678779602
# 'total_maps'
# match id - 31 ; time spent - 45.03829622268677
# 'total_maps'
# match id - 32 ; time spent - 46.32201623916626
# 'total_maps'
# match id - 33 ; time spent - 47.61224389076233
# 'total_maps'
# match id - 34 ; time spent - 49.11783766746521
# 'total_maps'
# match id - 35 ; time spent - 50.54033541679382
# 'total_maps'
# match id - 36 ; time spent - 51.79008913040161
# 'total_maps'
# match id - 37 ; time spent - 52.91322159767151
# 'total_maps'
# match id - 38 ; time spent - 54.02980279922485
# 'total_maps'
# match id - 39 ; time spent - 55.94802761077881
# 'total_maps'
# match id - 40 ; time spent - 57.09816336631775
# 'total_maps'
# match id - 41 ; time spent - 58.638346910476685
# 'total_maps'
# match id - 42 ; time spent - 59.70533275604248
# 'total_maps'
# match id - 43 ; time spent - 60.812378883361816
# 'total_maps'
# match id - 44 ; time spent - 62.24074029922485
# 'total_maps'
# match id - 45 ; time spent - 63.3545937538147
# 'total_maps'
# match id - 46 ; time spent - 64.50008296966553
# 'total_maps'
# match id - 47 ; time spent - 65.57734537124634
# 'total_maps'
# match id - 48 ; time spent - 67.07329487800598
# 'total_maps'
# match id - 49 ; time spent - 69.20434641838074
# 'total_maps'
# match id - 50 ; time spent - 71.40957450866699
# 'total_maps'
# match id - 51 ; time spent - 72.87993574142456
# 'total_maps'
# match id - 52 ; time spent - 74.5697615146637
# 'total_maps'
# match id - 53 ; time spent - 75.7952024936676
# 'total_maps'
# match id - 54 ; time spent - 77.90551495552063
# 'total_maps'
# match id - 55 ; time spent - 81.11956739425659
# 'total_maps'
# match id - 56 ; time spent - 82.25163531303406
# 'total_maps'
# match id - 57 ; time spent - 83.99333477020264
# 'total_maps'
# match id - 58 ; time spent - 85.40036368370056
# 'total_maps'
# match id - 59 ; time spent - 88.52739143371582
# 'total_maps'
# match id - 60 ; time spent - 89.6872136592865
# 'total_maps'
# match id - 61 ; time spent - 90.86705374717712
# 'total_maps'
# match id - 62 ; time spent - 92.2489333152771
# 'total_maps'
# match id - 63 ; time spent - 93.63215231895447
# 'total_maps'
# match id - 64 ; time spent - 94.75832176208496
# 'total_maps'
# match id - 65 ; time spent - 95.83632254600525
# 'total_maps'
# match id - 66 ; time spent - 97.16512060165405
# 'total_maps'
# match id - 67 ; time spent - 98.47826147079468
# 'total_maps'
# match id - 68 ; time spent - 100.47899436950684
# 'total_maps'
# match id - 69 ; time spent - 101.70685958862305
# 'total_maps'
# match id - 70 ; time spent - 103.06260347366333
# 'total_maps'
# match id - 71 ; time spent - 104.24082326889038
# 'total_maps'
# match id - 72 ; time spent - 105.47925305366516
# 'total_maps'
# match id - 73 ; time spent - 106.61492013931274
# 'total_maps'
# match id - 74 ; time spent - 107.90483093261719
# 'total_maps'
# match id - 75 ; time spent - 109.07791328430176
# 'total_maps'
# match id - 76 ; time spent - 110.17515158653259
# 'total_maps'
# match id - 77 ; time spent - 112.08638310432434
# 'total_maps'
# match id - 78 ; time spent - 113.17683529853821
# 'total_maps'
# match id - 79 ; time spent - 114.31801557540894
# 'total_maps'
# match id - 80 ; time spent - 115.57113456726074
# 'total_maps'
# match id - 81 ; time spent - 116.7070140838623
# 'total_maps'
# match id - 82 ; time spent - 117.96010518074036
# 'total_maps'
# match id - 83 ; time spent - 119.8243236541748
# 'total_maps'
# match id - 84 ; time spent - 120.89724087715149
# 'total_maps'
# match id - 85 ; time spent - 121.9330084323883
# 'total_maps'
# match id - 86 ; time spent - 123.15346145629883
# 'total_maps'
# match id - 87 ; time spent - 124.53903651237488
# 'total_maps'
# match id - 88 ; time spent - 126.30330681800842
# 'total_maps'
# match id - 89 ; time spent - 127.41926550865173
# 'total_maps'
# match id - 90 ; time spent - 128.5670142173767
# 'total_maps'
# match id - 91 ; time spent - 129.69790387153625
# 'total_maps'
# match id - 92 ; time spent - 130.91179418563843
# 'total_maps'
# match id - 93 ; time spent - 132.75007390975952
# 'total_maps'
# match id - 94 ; time spent - 134.38254237174988
# 'total_maps'
# match id - 95 ; time spent - 135.43280816078186
# 'total_maps'
# match id - 96 ; time spent - 136.6228325366974
# 'total_maps'
# match id - 97 ; time spent - 138.39327931404114
# 'total_maps'
# match id - 98 ; time spent - 139.54018807411194
# 'total_maps'
# match id - 99 ; time spent - 140.48113703727722
# 'total_maps'
# match id - 100 ; time spent - 141.90679717063904
# 'total_maps'
# match id - 101 ; time spent - 143.04407000541687
# 'total_maps'
# match id - 102 ; time spent - 144.60284996032715
# 'total_maps'
# match id - 103 ; time spent - 146.33153104782104
# 'total_maps'
# match id - 104 ; time spent - 147.39816999435425
# 'total_maps'
# match id - 105 ; time spent - 148.99527764320374
# 'total_maps'
# match id - 106 ; time spent - 150.70777010917664
# 'total_maps'
# match id - 107 ; time spent - 151.85364890098572
# 'total_maps'
# match id - 108 ; time spent - 153.0237536430359
# 'total_maps'
# match id - 109 ; time spent - 154.34486317634583
# 'total_maps'
# match id - 110 ; time spent - 156.2426643371582
# 'total_maps'
# match id - 111 ; time spent - 157.83483600616455
# 'total_maps'
# match id - 112 ; time spent - 158.89095544815063
# 'total_maps'
# match id - 113 ; time spent - 160.45571851730347
# 'total_maps'
# match id - 114 ; time spent - 161.79809141159058
# 'total_maps'
# match id - 115 ; time spent - 163.60281682014465
# 'total_maps'
# match id - 116 ; time spent - 164.67033290863037
# 'total_maps'
# match id - 117 ; time spent - 166.0497281551361
# 'total_maps'
# match id - 118 ; time spent - 167.12279605865479
# 'total_maps'
# match id - 119 ; time spent - 168.2454445362091
# 'total_maps'
# match id - 120 ; time spent - 170.15147376060486
# 'total_maps'
# match id - 121 ; time spent - 171.65896582603455
# 'total_maps'
# match id - 122 ; time spent - 173.96950912475586
# 'total_maps'
# match id - 123 ; time spent - 175.30650115013123
# 'total_maps'
# match id - 124 ; time spent - 176.7820065021515
# 'total_maps'
# match id - 125 ; time spent - 178.48728132247925
# 'total_maps'
# match id - 126 ; time spent - 180.0572488307953
# 'NoneType' object is not subscriptable
# match id - 127 ; time spent - 180.86183500289917
# 'total_maps'
# match id - 128 ; time spent - 183.07640624046326
# 'total_maps'
# match id - 129 ; time spent - 184.6831555366516
# 'NoneType' object is not subscriptable
# match id - 130 ; time spent - 186.2192783355713
# 'total_maps'
# match id - 131 ; time spent - 187.37471199035645
# 'total_maps'
# match id - 132 ; time spent - 188.53496646881104
# 'total_maps'
# match id - 133 ; time spent - 189.8209352493286
# 'total_maps'
# match id - 134 ; time spent - 191.85460710525513
# 'total_maps'
# match id - 135 ; time spent - 193.39002871513367
# 'total_maps'
# match id - 136 ; time spent - 194.65525770187378
# 'total_maps'
# match id - 137 ; time spent - 196.1574764251709
# 'total_maps'
# match id - 138 ; time spent - 197.3561863899231
# 'total_maps'
# match id - 139 ; time spent - 198.61266088485718
# 'total_maps'
# match id - 140 ; time spent - 199.97624850273132
# 'total_maps'
# match id - 141 ; time spent - 201.12263298034668
# 'total_maps'
# match id - 142 ; time spent - 203.02392840385437
# 'total_maps'
# match id - 143 ; time spent - 204.26951479911804
# 'total_maps'
# match id - 144 ; time spent - 205.52420091629028
# 'total_maps'
# match id - 145 ; time spent - 206.73211121559143
# 'total_maps'
# match id - 146 ; time spent - 208.08934450149536
# 'total_maps'
# match id - 147 ; time spent - 209.13953971862793
# 'total_maps'
# match id - 148 ; time spent - 210.4636206626892
# 'total_maps'
# match id - 149 ; time spent - 212.2205150127411
# 'total_maps'
# match id - 150 ; time spent - 214.31435227394104
# 'total_maps'
# match id - 151 ; time spent - 216.23020362854004
# 'NoneType' object is not subscriptable
# match id - 152 ; time spent - 217.91675782203674
# 'total_maps'
# match id - 153 ; time spent - 219.39689469337463
# 'total_maps'
# match id - 154 ; time spent - 220.8034689426422
# 'total_maps'
# match id - 155 ; time spent - 222.23576617240906
# 'total_maps'
# match id - 156 ; time spent - 223.28019857406616
# 'NoneType' object is not subscriptable
# match id - 157 ; time spent - 224.04493236541748
# 'total_maps'
# match id - 158 ; time spent - 225.3477864265442
# 'total_maps'
# match id - 159 ; time spent - 226.4513976573944
# 'total_maps'
# match id - 160 ; time spent - 227.57159113883972
# 'total_maps'
# match id - 161 ; time spent - 229.413067817688
# 'total_maps'
# match id - 162 ; time spent - 230.57140707969666
# 'total_maps'
# match id - 163 ; time spent - 232.47559762001038
# 'total_maps'
# match id - 164 ; time spent - 234.166565656662
# 'total_maps'
# match id - 165 ; time spent - 237.25624561309814
# 'total_maps'
# match id - 166 ; time spent - 240.7421133518219
# 'total_maps'
# match id - 167 ; time spent - 241.82091808319092
# 'total_maps'
# match id - 168 ; time spent - 243.24033308029175
# 'total_maps'
# match id - 169 ; time spent - 244.64942049980164
# 'total_maps'
# match id - 170 ; time spent - 245.86794257164001
# 'total_maps'
# match id - 171 ; time spent - 247.20937991142273
# 'total_maps'
# match id - 172 ; time spent - 248.52691221237183
# 'total_maps'
# match id - 173 ; time spent - 249.8147327899933
# 'total_maps'
# match id - 174 ; time spent - 251.16784572601318
# 'NoneType' object is not subscriptable
# match id - 175 ; time spent - 252.67052555084229
# 'total_maps'
# match id - 176 ; time spent - 253.814284324646
# 'total_maps'
# match id - 177 ; time spent - 254.8480508327484
# 'total_maps'
# match id - 178 ; time spent - 255.99104809761047
# 'NoneType' object is not subscriptable
# match id - 179 ; time spent - 256.71837615966797
# 'total_maps'
# match id - 180 ; time spent - 258.7220687866211
# 'total_maps'
# match id - 181 ; time spent - 262.0117573738098
# 'total_maps'
# match id - 182 ; time spent - 263.42686319351196
# 'total_maps'
# match id - 183 ; time spent - 264.68370294570923
# 'total_maps'
# match id - 184 ; time spent - 265.78597688674927
# 'total_maps'
# match id - 185 ; time spent - 267.31890535354614
# 'total_maps'
# match id - 186 ; time spent - 268.58245277404785
# 'total_maps'
# match id - 187 ; time spent - 270.93237257003784
# 'total_maps'
# match id - 188 ; time spent - 272.06035923957825
# 'total_maps'
# match id - 189 ; time spent - 273.2523853778839
# 'total_maps'
# match id - 190 ; time spent - 274.7553119659424
# 'total_maps'
# match id - 191 ; time spent - 275.91511607170105
# 'total_maps'
# match id - 192 ; time spent - 279.4591631889343
# 'total_maps'
# match id - 193 ; time spent - 280.8902049064636
# 'total_maps'
# match id - 194 ; time spent - 281.9315276145935
# 'total_maps'
# match id - 195 ; time spent - 283.07156682014465
# 'total_maps'
# match id - 196 ; time spent - 285.196950674057
# 'total_maps'
# match id - 197 ; time spent - 286.7222180366516
# 'total_maps'
# match id - 198 ; time spent - 288.15758872032166
# 'total_maps'
# match id - 199 ; time spent - 289.46878004074097
# 'total_maps'
# match id - 200 ; time spent - 290.6416518688202
# 'total_maps'
# match id - 201 ; time spent - 292.65266370773315
# 'total_maps'
# match id - 202 ; time spent - 293.75880432128906
# 'total_maps'
# match id - 203 ; time spent - 295.22706866264343
# 'total_maps'
# match id - 204 ; time spent - 296.638662815094
# 'total_maps'
# match id - 205 ; time spent - 297.9299600124359
# 'total_maps'
# match id - 206 ; time spent - 299.4120366573334
# 'total_maps'
# match id - 207 ; time spent - 300.7454090118408
# 'total_maps'
# match id - 208 ; time spent - 301.94592213630676
# 'total_maps'
# match id - 209 ; time spent - 303.7305407524109
# 'total_maps'
# match id - 210 ; time spent - 305.2466173171997
# 'total_maps'
# match id - 211 ; time spent - 306.63950538635254
# 'total_maps'
# match id - 212 ; time spent - 308.42660188674927
# 'total_maps'
# match id - 213 ; time spent - 309.86053109169006
# 'total_maps'
# match id - 214 ; time spent - 311.48463201522827
# 'total_maps'
# match id - 215 ; time spent - 312.88099789619446
# 'total_maps'
# match id - 216 ; time spent - 314.1977870464325
# 'total_maps'
# match id - 217 ; time spent - 316.0480959415436
# 'total_maps'
# match id - 218 ; time spent - 317.18742275238037
# 'total_maps'
# match id - 219 ; time spent - 318.66396737098694
# 'total_maps'
# match id - 220 ; time spent - 319.9946446418762
# 'total_maps'
# match id - 221 ; time spent - 321.45239424705505
# 'total_maps'
# match id - 222 ; time spent - 322.8825144767761
# 'total_maps'
# match id - 223 ; time spent - 323.87503933906555
# 'total_maps'
# match id - 224 ; time spent - 325.4182415008545
# 'total_maps'
# match id - 225 ; time spent - 326.79500365257263
# 'total_maps'
# match id - 226 ; time spent - 327.9949240684509
# 'total_maps'
# match id - 227 ; time spent - 329.17769956588745
# 'total_maps'
# match id - 228 ; time spent - 330.24156308174133
# 'total_maps'
# match id - 229 ; time spent - 331.2092685699463
# 'total_maps'
# match id - 230 ; time spent - 332.6148838996887
# 'total_maps'
# match id - 231 ; time spent - 334.0245134830475
# 'total_maps'
# match id - 232 ; time spent - 335.6070981025696
# 'total_maps'
# match id - 233 ; time spent - 336.65848302841187
# 'total_maps'
# match id - 234 ; time spent - 337.97039127349854
# 'total_maps'
# match id - 235 ; time spent - 339.020751953125
# 'total_maps'
# match id - 236 ; time spent - 340.0859422683716
# 'NoneType' object is not subscriptable
# match id - 237 ; time spent - 341.2197787761688
# 'total_maps'
# match id - 238 ; time spent - 342.6488039493561
# 'total_maps'
# match id - 239 ; time spent - 343.8324513435364
# 'NoneType' object is not subscriptable
# match id - 240 ; time spent - 344.7333197593689
# 'total_maps'
# match id - 241 ; time spent - 346.13753724098206
# 'total_maps'
# match id - 242 ; time spent - 347.63958764076233
# 'total_maps'
# match id - 243 ; time spent - 349.0492088794708
# 'total_maps'
# match id - 244 ; time spent - 350.4859571456909
# 'total_maps'
# match id - 245 ; time spent - 351.75723242759705
# 'total_maps'
# match id - 246 ; time spent - 352.9373986721039
# 'total_maps'
# match id - 247 ; time spent - 354.17956924438477
# 'total_maps'
# match id - 248 ; time spent - 355.4886040687561
# 'total_maps'
# match id - 249 ; time spent - 356.5023627281189
# 'total_maps'
# match id - 250 ; time spent - 357.76841974258423
# 'total_maps'
# match id - 251 ; time spent - 358.9082610607147
# 'total_maps'
# match id - 252 ; time spent - 360.0488669872284
# 'total_maps'
# match id - 253 ; time spent - 361.2091727256775
# 'total_maps'
# match id - 254 ; time spent - 362.21054887771606
# 'total_maps'
# match id - 255 ; time spent - 363.4958236217499
# 'total_maps'
# match id - 256 ; time spent - 365.0212142467499
# 'total_maps'
# match id - 257 ; time spent - 366.267297744751
# 'total_maps'
# match id - 258 ; time spent - 367.38523745536804
# 'total_maps'
# match id - 259 ; time spent - 368.8412272930145
# 'NoneType' object is not subscriptable
# match id - 260 ; time spent - 369.7460472583771
# 'total_maps'
# match id - 261 ; time spent - 371.19879126548767
# 'total_maps'
# match id - 262 ; time spent - 372.31844758987427
# 'total_maps'
# match id - 263 ; time spent - 373.68322587013245
# 'NoneType' object is not subscriptable
# match id - 264 ; time spent - 374.53559708595276
# 'total_maps'
# match id - 265 ; time spent - 375.5524809360504
# 'total_maps'
# match id - 266 ; time spent - 376.5410313606262
# 'total_maps'
# match id - 267 ; time spent - 377.52323842048645
# 'NoneType' object is not subscriptable
# match id - 268 ; time spent - 378.40585064888
# 'total_maps'
# match id - 269 ; time spent - 379.32794094085693
# 'NoneType' object is not subscriptable
# match id - 270 ; time spent - 380.28244614601135
# 'total_maps'
# match id - 271 ; time spent - 381.21178340911865
# 'NoneType' object is not subscriptable
# match id - 272 ; time spent - 382.12775111198425
# 'total_maps'
# match id - 273 ; time spent - 383.17258882522583
# 'total_maps'
# match id - 274 ; time spent - 385.22203516960144
# 'NoneType' object is not subscriptable
# match id - 275 ; time spent - 386.106436252594
# 'total_maps'
# match id - 276 ; time spent - 387.89132475852966
# 'total_maps'
# match id - 277 ; time spent - 389.05573868751526
# 'total_maps'
# match id - 278 ; time spent - 390.2618591785431
# 'total_maps'
# match id - 279 ; time spent - 392.4384729862213
# 'total_maps'
# match id - 280 ; time spent - 393.5578877925873
# 'total_maps'
# match id - 281 ; time spent - 394.68988037109375
# 'total_maps'
# match id - 282 ; time spent - 395.77058839797974
# 'total_maps'
# match id - 283 ; time spent - 397.18816566467285
# 'total_maps'
# match id - 284 ; time spent - 398.37654638290405
# 'total_maps'
# match id - 285 ; time spent - 399.6711657047272
# 'total_maps'
# match id - 286 ; time spent - 400.5910267829895
# 'total_maps'
# match id - 287 ; time spent - 403.90337443351746
# 'total_maps'
# match id - 288 ; time spent - 404.9783353805542
# 'total_maps'
# match id - 289 ; time spent - 405.93758368492126
# 'total_maps'
# match id - 290 ; time spent - 406.940851688385
# 'total_maps'
# match id - 291 ; time spent - 409.02705430984497
# 'total_maps'
# match id - 292 ; time spent - 410.1041331291199
# 'total_maps'
# match id - 293 ; time spent - 411.6163947582245
# 'total_maps'
# match id - 294 ; time spent - 412.8151218891144
# 'total_maps'
# match id - 295 ; time spent - 413.98888301849365
# 'total_maps'
# match id - 296 ; time spent - 415.29189682006836
# 'total_maps'
# match id - 297 ; time spent - 416.51300740242004
# 'total_maps'
# match id - 298 ; time spent - 417.81309032440186
# 'total_maps'
# match id - 299 ; time spent - 419.54789113998413
# 'total_maps'
# match id - 300 ; time spent - 420.78019857406616
# 'total_maps'
# match id - 301 ; time spent - 422.0470561981201
# 'total_maps'
# match id - 302 ; time spent - 428.0021767616272
# 'total_maps'
# match id - 303 ; time spent - 429.1340072154999
# 'total_maps'
# match id - 304 ; time spent - 430.2816791534424
# 'total_maps'
# match id - 305 ; time spent - 431.26511120796204
# 'total_maps'
# match id - 306 ; time spent - 432.36126494407654
# 'total_maps'
# match id - 307 ; time spent - 433.63858437538147
# 'total_maps'
# match id - 308 ; time spent - 435.5206370353699
# 'total_maps'
# match id - 309 ; time spent - 436.6384165287018
# 'total_maps'
# match id - 310 ; time spent - 437.7407913208008
# 'total_maps'
# match id - 311 ; time spent - 438.9886701107025
# 'total_maps'
# match id - 312 ; time spent - 440.91305685043335
# 'total_maps'
# match id - 313 ; time spent - 442.3755581378937
# 'total_maps'
# match id - 314 ; time spent - 443.4628760814667
# 'total_maps'
# match id - 315 ; time spent - 444.72548627853394
# 'total_maps'
# match id - 316 ; time spent - 445.71436619758606
# 'total_maps'
# match id - 317 ; time spent - 447.57394790649414
# 'total_maps'
# match id - 318 ; time spent - 448.6770167350769
# 'total_maps'
# match id - 319 ; time spent - 449.6335120201111
# 'total_maps'
# match id - 320 ; time spent - 450.84816336631775
# 'total_maps'
# match id - 321 ; time spent - 451.95131063461304
# 'total_maps'
# match id - 322 ; time spent - 453.66641306877136
# 'total_maps'
# match id - 323 ; time spent - 455.19484424591064
# 'total_maps'
# match id - 324 ; time spent - 456.2296333312988
# 'total_maps'
# match id - 325 ; time spent - 459.33361768722534
# 'total_maps'
# match id - 326 ; time spent - 460.433230638504
# 'total_maps'
# match id - 327 ; time spent - 463.5661954879761
# 'total_maps'
# match id - 328 ; time spent - 464.7368607521057
# 'total_maps'
# match id - 329 ; time spent - 465.7846279144287
# 'NoneType' object is not subscriptable
# match id - 330 ; time spent - 466.8649513721466
# 'total_maps'
# match id - 331 ; time spent - 468.3881776332855
# 'total_maps'
# match id - 332 ; time spent - 471.6411249637604
# 'total_maps'
# match id - 333 ; time spent - 472.8868327140808
# 'total_maps'
# match id - 334 ; time spent - 474.13350009918213
# 'total_maps'
# match id - 335 ; time spent - 475.64812421798706
# 'total_maps'
# match id - 336 ; time spent - 477.0389566421509
# 'total_maps'
# match id - 337 ; time spent - 478.89590191841125
# 'NoneType' object is not subscriptable
# match id - 338 ; time spent - 479.7916543483734
# 'NoneType' object is not subscriptable
# match id - 339 ; time spent - 480.6901979446411
# 'total_maps'
# match id - 340 ; time spent - 481.9473614692688
# 'total_maps'
# match id - 341 ; time spent - 484.0178520679474
# 'total_maps'
# match id - 342 ; time spent - 485.2580816745758
# 'NoneType' object is not subscriptable
# match id - 343 ; time spent - 486.1867651939392
# 'NoneType' object is not subscriptable
# match id - 344 ; time spent - 486.9731698036194
# 'total_maps'
# match id - 345 ; time spent - 488.1732647418976
# 'total_maps'
# match id - 346 ; time spent - 489.38608050346375
# 'total_maps'
# match id - 347 ; time spent - 490.47458839416504
# 'total_maps'
# match id - 348 ; time spent - 491.6628041267395
# 'total_maps'
# match id - 349 ; time spent - 493.01904582977295
# 'total_maps'
# match id - 350 ; time spent - 494.7336049079895
# 'total_maps'
# match id - 351 ; time spent - 496.2575490474701
# 'total_maps'
# match id - 352 ; time spent - 497.67535877227783
# 'total_maps'
# match id - 353 ; time spent - 498.80964946746826
# 'total_maps'
# match id - 354 ; time spent - 500.10943722724915
# 'total_maps'
# match id - 355 ; time spent - 501.22143626213074
# 'total_maps'
# match id - 356 ; time spent - 502.66346621513367
# 'total_maps'
# match id - 357 ; time spent - 504.5764191150665
# 'total_maps'
# match id - 358 ; time spent - 505.74428129196167
# 'total_maps'
# match id - 359 ; time spent - 506.8304662704468
# 'total_maps'
# match id - 360 ; time spent - 508.18922233581543
# 'total_maps'
# match id - 361 ; time spent - 509.3238899707794
# 'total_maps'
# match id - 362 ; time spent - 510.4459705352783
# 'total_maps'
# match id - 363 ; time spent - 511.6044623851776
# 'total_maps'
# match id - 364 ; time spent - 512.9071807861328
# 'total_maps'
# match id - 365 ; time spent - 514.4177763462067
# 'total_maps'
# match id - 366 ; time spent - 515.7300522327423
# 'total_maps'
# match id - 367 ; time spent - 516.8787460327148
# 'total_maps'
# match id - 368 ; time spent - 518.2816271781921
# 'total_maps'
# match id - 369 ; time spent - 519.4857873916626
# 'total_maps'
# match id - 370 ; time spent - 521.0984842777252
# 'total_maps'
# match id - 371 ; time spent - 522.2313852310181
# 'total_maps'
# match id - 372 ; time spent - 523.3849709033966
# 'total_maps'
# match id - 373 ; time spent - 524.628087759018
# 'total_maps'
# match id - 374 ; time spent - 526.0524039268494
# 'total_maps'
# match id - 375 ; time spent - 527.4382565021515
# 'total_maps'
# match id - 376 ; time spent - 528.6151444911957
# 'total_maps'
# match id - 377 ; time spent - 529.7963643074036
# 'total_maps'
# match id - 378 ; time spent - 531.2390842437744
# 'total_maps'
# match id - 379 ; time spent - 532.3291575908661
# 'total_maps'
# match id - 380 ; time spent - 534.6014184951782
# 'total_maps'
# match id - 381 ; time spent - 536.0713732242584
# 'total_maps'
# match id - 382 ; time spent - 537.3577334880829
# 'total_maps'
# match id - 383 ; time spent - 539.2589321136475
# 'total_maps'
# match id - 384 ; time spent - 540.6633884906769
# 'total_maps'
# match id - 385 ; time spent - 541.9568064212799
# 'total_maps'
# match id - 386 ; time spent - 543.0990252494812
# 'total_maps'
# match id - 387 ; time spent - 544.449723482132
# 'total_maps'
# match id - 388 ; time spent - 545.5774576663971
# 'NoneType' object is not subscriptable
# match id - 389 ; time spent - 547.1177923679352
# 'total_maps'
# match id - 390 ; time spent - 548.3915648460388
# 'total_maps'
# match id - 391 ; time spent - 550.1338419914246
# 'total_maps'
# match id - 392 ; time spent - 551.5185601711273
# 'total_maps'
# match id - 393 ; time spent - 552.8880772590637
# 'total_maps'
# match id - 394 ; time spent - 554.0382225513458
# 'total_maps'
# match id - 395 ; time spent - 555.3877601623535
# 'total_maps'
# match id - 396 ; time spent - 557.3947062492371
# 'NoneType' object is not subscriptable
# match id - 397 ; time spent - 558.2012851238251
# 'NoneType' object is not subscriptable
# match id - 398 ; time spent - 559.5998678207397
# 'NoneType' object is not subscriptable
# match id - 399 ; time spent - 560.464928150177
# 'NoneType' object is not subscriptable
# match id - 400 ; time spent - 562.0052628517151
# 'total_maps'
# match id - 401 ; time spent - 563.359432220459
# 'total_maps'
# match id - 402 ; time spent - 565.1445002555847
# 'total_maps'
# match id - 403 ; time spent - 567.92018866539
# 'total_maps'
# match id - 404 ; time spent - 569.3732345104218
# 'total_maps'
# match id - 405 ; time spent - 570.4066705703735
# 'total_maps'
# match id - 406 ; time spent - 571.6164388656616
# 'total_maps'
# match id - 407 ; time spent - 572.830826997757
# 'total_maps'
# match id - 408 ; time spent - 574.0275118350983
# 'total_maps'
# match id - 409 ; time spent - 575.2007920742035
# 'total_maps'
# match id - 410 ; time spent - 576.3294072151184
# 'total_maps'
# match id - 411 ; time spent - 577.6627712249756
# 'total_maps'
# match id - 412 ; time spent - 579.652361869812
# 'total_maps'
# match id - 413 ; time spent - 581.0038058757782
# 'total_maps'
# match id - 414 ; time spent - 582.219509601593
# 'total_maps'
# match id - 415 ; time spent - 584.0328197479248
# 'total_maps'
# match id - 416 ; time spent - 585.4690351486206
# 'NoneType' object is not subscriptable
# match id - 417 ; time spent - 586.6123583316803
# 'NoneType' object is not subscriptable
# match id - 418 ; time spent - 587.9643948078156
# 'NoneType' object is not subscriptable
# match id - 419 ; time spent - 591.4991445541382
# 'total_maps'
# match id - 420 ; time spent - 593.1034126281738
# 'total_maps'
# match id - 421 ; time spent - 594.3606503009796
# 'total_maps'
# match id - 422 ; time spent - 595.5862848758698
# 'total_maps'
# match id - 423 ; time spent - 597.1488962173462
# 'total_maps'
# match id - 424 ; time spent - 599.1655068397522
# 'total_maps'
# match id - 425 ; time spent - 600.682776927948
# 'total_maps'
# match id - 426 ; time spent - 601.9260609149933
# 'total_maps'
# match id - 427 ; time spent - 603.4282779693604
# 'total_maps'
# match id - 428 ; time spent - 605.4006025791168
# 'total_maps'
# match id - 429 ; time spent - 606.7564792633057
# 'total_maps'
# match id - 430 ; time spent - 608.160647392273
# 'total_maps'
# match id - 431 ; time spent - 609.5365285873413
# 'NoneType' object is not subscriptable
# match id - 432 ; time spent - 610.5024712085724
# 'total_maps'
# match id - 433 ; time spent - 611.6648063659668
# 'total_maps'
# match id - 434 ; time spent - 614.4843542575836
# 'total_maps'
# match id - 435 ; time spent - 615.9521887302399
# 'total_maps'
# match id - 436 ; time spent - 617.8921663761139
# 'total_maps'
# match id - 437 ; time spent - 619.3326277732849
# 'total_maps'
# match id - 438 ; time spent - 620.7156376838684
# 'total_maps'
# match id - 439 ; time spent - 622.0588233470917
# 'total_maps'
# match id - 440 ; time spent - 623.6124567985535
# 'total_maps'
# match id - 441 ; time spent - 624.884603023529
# 'NoneType' object is not subscriptable
# match id - 442 ; time spent - 626.8089714050293
# 'total_maps'
# match id - 443 ; time spent - 628.3358373641968
# 'total_maps'
# match id - 444 ; time spent - 630.0739026069641
# 'total_maps'
# match id - 445 ; time spent - 631.4673268795013
# 'NoneType' object is not subscriptable
# match id - 446 ; time spent - 632.3636381626129
# 'NoneType' object is not subscriptable
# match id - 447 ; time spent - 633.3386418819427
# 'total_maps'
# match id - 448 ; time spent - 634.6730508804321
# 'total_maps'
# match id - 449 ; time spent - 635.7561507225037
# 'total_maps'
# match id - 450 ; time spent - 637.0527756214142
# 'total_maps'
# match id - 451 ; time spent - 638.1805312633514
# 'total_maps'
# match id - 452 ; time spent - 639.3511419296265
# 'total_maps'
# match id - 453 ; time spent - 640.333981513977
# 'total_maps'
# match id - 454 ; time spent - 641.4615380764008
# 'total_maps'
# match id - 455 ; time spent - 642.9598894119263
# 'total_maps'
# match id - 456 ; time spent - 644.4977080821991
# 'total_maps'
# match id - 457 ; time spent - 645.6292779445648
# 'total_maps'
# match id - 458 ; time spent - 646.7706427574158
# 'total_maps'
# match id - 459 ; time spent - 648.0559434890747
# 'total_maps'
# match id - 460 ; time spent - 650.8346054553986
# 'total_maps'
# match id - 461 ; time spent - 653.972437620163
# 'total_maps'
# match id - 462 ; time spent - 655.0770211219788
# 'total_maps'
# match id - 463 ; time spent - 656.312352180481
# 'total_maps'
# match id - 464 ; time spent - 657.4283621311188
# 'total_maps'
# match id - 465 ; time spent - 658.5029394626617
# 'total_maps'
# match id - 466 ; time spent - 659.5968437194824
# 'total_maps'
# match id - 467 ; time spent - 661.4133155345917
# 'total_maps'
# match id - 468 ; time spent - 662.7456254959106
# 'total_maps'
# match id - 469 ; time spent - 664.2753782272339
# 'total_maps'
# match id - 470 ; time spent - 665.3811070919037
# 'total_maps'
# match id - 471 ; time spent - 666.7509050369263
# 'total_maps'
# match id - 472 ; time spent - 667.9322710037231
# 'total_maps'
# match id - 473 ; time spent - 669.5176105499268
# 'total_maps'
# match id - 474 ; time spent - 670.610194683075
# 'total_maps'
# match id - 475 ; time spent - 672.033857345581
# 'total_maps'
# match id - 476 ; time spent - 673.4943208694458
# 'total_maps'
# match id - 477 ; time spent - 675.0886270999908
# 'total_maps'
# match id - 478 ; time spent - 676.4834673404694
# 'NoneType' object is not subscriptable
# match id - 479 ; time spent - 677.5119295120239
# 'total_maps'
# match id - 480 ; time spent - 678.8618538379669
# 'total_maps'
# match id - 481 ; time spent - 680.2492117881775
# 'total_maps'
# match id - 482 ; time spent - 681.4715428352356
# 'total_maps'
# match id - 483 ; time spent - 683.5438776016235
# 'NoneType' object is not subscriptable
# match id - 484 ; time spent - 684.3974080085754
# 'total_maps'
# match id - 485 ; time spent - 685.5686409473419
# 'total_maps'
# match id - 486 ; time spent - 686.9087378978729
# 'total_maps'
# match id - 487 ; time spent - 688.1572496891022
# 'total_maps'
# match id - 488 ; time spent - 689.3408155441284
# 'NoneType' object is not subscriptable
# match id - 489 ; time spent - 690.6600692272186
# 'total_maps'
# match id - 490 ; time spent - 691.8354337215424
# 'total_maps'
# match id - 491 ; time spent - 693.0954217910767
# 'total_maps'
# match id - 492 ; time spent - 694.8779091835022
# 'total_maps'
# match id - 493 ; time spent - 695.9673163890839
# 'total_maps'
# match id - 494 ; time spent - 696.9006104469299
# 'total_maps'
# match id - 495 ; time spent - 698.8026781082153
# 'total_maps'
# match id - 496 ; time spent - 700.0142035484314
# 'NoneType' object is not subscriptable
# match id - 497 ; time spent - 700.9432489871979
# 'total_maps'
# match id - 498 ; time spent - 702.7806346416473
# 'total_maps'
# match id - 499 ; time spent - 704.5553233623505
# 'total_maps'
# match id - 500 ; time spent - 706.0577981472015
# 'total_maps'
# match id - 501 ; time spent - 707.810772895813
# 'total_maps'
# match id - 502 ; time spent - 708.9050545692444
# 'total_maps'
# match id - 503 ; time spent - 710.2761325836182
# 'total_maps'
# match id - 504 ; time spent - 711.6148819923401
# 'total_maps'
# match id - 505 ; time spent - 712.7700853347778
# 'total_maps'
# match id - 506 ; time spent - 713.9088501930237
# 'total_maps'
# match id - 507 ; time spent - 715.130942106247
# 'total_maps'
# match id - 508 ; time spent - 718.6349506378174
# 'total_maps'
# match id - 509 ; time spent - 720.1302070617676
# 'total_maps'
# match id - 510 ; time spent - 721.2596900463104
# 'total_maps'
# match id - 511 ; time spent - 723.0041794776917
# 'total_maps'
# match id - 512 ; time spent - 724.9324765205383
# 'total_maps'
# match id - 513 ; time spent - 727.0927817821503
# 'total_maps'
# match id - 514 ; time spent - 728.7265157699585
# 'total_maps'
# match id - 515 ; time spent - 730.6437532901764
# 'total_maps'
# match id - 516 ; time spent - 731.9216351509094
# 'total_maps'
# match id - 517 ; time spent - 733.3939678668976
# 'total_maps'
# match id - 518 ; time spent - 734.6779277324677
# 'total_maps'
# match id - 519 ; time spent - 736.006646156311
# 'total_maps'
# match id - 520 ; time spent - 737.2763817310333
# 'total_maps'
# match id - 521 ; time spent - 738.742348909378
# 'total_maps'
# match id - 522 ; time spent - 740.8328220844269
# 'total_maps'
# match id - 523 ; time spent - 742.1891582012177
# 'total_maps'
# match id - 524 ; time spent - 743.2825520038605
# 'total_maps'
# match id - 525 ; time spent - 744.6580364704132
# 'total_maps'
# match id - 526 ; time spent - 745.8425359725952
# 'total_maps'
# match id - 527 ; time spent - 747.0111711025238
# 'total_maps'
# match id - 528 ; time spent - 748.1508500576019
# 'total_maps'
# match id - 529 ; time spent - 749.2483005523682
# 'total_maps'
# match id - 530 ; time spent - 750.2850751876831
# 'total_maps'
# match id - 531 ; time spent - 751.5761559009552
# 'total_maps'
# match id - 532 ; time spent - 752.7854406833649
# 'total_maps'
# match id - 533 ; time spent - 753.8431439399719
# 'total_maps'
# match id - 534 ; time spent - 755.1741139888763
# 'total_maps'
# match id - 535 ; time spent - 756.6032559871674
# 'total_maps'
# match id - 536 ; time spent - 757.9867758750916
# 'total_maps'
# match id - 537 ; time spent - 760.1772882938385
# 'total_maps'
# match id - 538 ; time spent - 762.0326130390167
# 'total_maps'
# match id - 539 ; time spent - 763.2272424697876
# 'total_maps'
# match id - 540 ; time spent - 764.3022830486298
# 'total_maps'
# match id - 541 ; time spent - 766.0093550682068
# 'total_maps'
# match id - 542 ; time spent - 767.3321313858032
# 'total_maps'
# match id - 543 ; time spent - 768.4395387172699
# 'NoneType' object is not subscriptable
# match id - 544 ; time spent - 769.3258852958679
# 'total_maps'
# match id - 545 ; time spent - 771.1441888809204
# 'total_maps'
# match id - 546 ; time spent - 772.4901881217957
# 'total_maps'
# match id - 547 ; time spent - 773.7568612098694
# 'total_maps'
# match id - 548 ; time spent - 775.1018667221069
# 'total_maps'
# match id - 549 ; time spent - 776.4675691127777
# 'total_maps'
# match id - 550 ; time spent - 777.8630185127258
# 'total_maps'
# match id - 551 ; time spent - 780.0370395183563
# 'total_maps'
# match id - 552 ; time spent - 781.4126029014587
# 'total_maps'
# match id - 553 ; time spent - 782.7316193580627
# 'total_maps'
# match id - 554 ; time spent - 783.9251337051392
# 'total_maps'
# match id - 555 ; time spent - 785.4085745811462
# 'total_maps'
# match id - 556 ; time spent - 786.6768913269043
# 'total_maps'
# match id - 557 ; time spent - 787.9886574745178
# 'total_maps'
# match id - 558 ; time spent - 789.2701642513275
# 'NoneType' object is not subscriptable
# match id - 559 ; time spent - 790.1412470340729
# 'total_maps'
# match id - 560 ; time spent - 791.2985470294952
# 'total_maps'
# match id - 561 ; time spent - 792.9599282741547
# 'total_maps'
# match id - 562 ; time spent - 794.0926103591919
# 'total_maps'
# match id - 563 ; time spent - 795.2983245849609
# 'total_maps'
# match id - 564 ; time spent - 796.5554616451263
# 'total_maps'
# match id - 565 ; time spent - 797.6979494094849
# 'total_maps'
# match id - 566 ; time spent - 799.4283955097198
# 'total_maps'
# match id - 567 ; time spent - 800.5244815349579
# 'total_maps'
# match id - 568 ; time spent - 802.7847652435303
# 'total_maps'
# match id - 569 ; time spent - 804.562310218811
# 'total_maps'
# match id - 570 ; time spent - 805.720771074295
# 'total_maps'
# match id - 571 ; time spent - 807.2310075759888
# 'total_maps'
# match id - 572 ; time spent - 808.5999999046326
# 'total_maps'
# match id - 573 ; time spent - 809.7592220306396
# 'total_maps'
# match id - 574 ; time spent - 811.2654116153717
# 'total_maps'
# match id - 575 ; time spent - 812.3689827919006
# 'total_maps'
# match id - 576 ; time spent - 813.4448516368866
# 'total_maps'
# match id - 577 ; time spent - 814.7129051685333
# 'total_maps'
# match id - 578 ; time spent - 816.0496227741241
# 'total_maps'
# match id - 579 ; time spent - 817.361688375473
# 'total_maps'
# match id - 580 ; time spent - 818.7570397853851
# 'total_maps'
# match id - 581 ; time spent - 821.1530818939209
# 'total_maps'
# match id - 582 ; time spent - 822.5027604103088
# 'total_maps'
# match id - 583 ; time spent - 823.6633672714233
# 'total_maps'
# match id - 584 ; time spent - 824.9496035575867
# 'total_maps'
# match id - 585 ; time spent - 826.1708269119263
# 'total_maps'
# match id - 586 ; time spent - 827.4673025608063
# 'total_maps'
# match id - 587 ; time spent - 828.6411023139954
# 'total_maps'
# match id - 588 ; time spent - 829.9037413597107
# 'total_maps'
# match id - 589 ; time spent - 831.4545590877533
# 'total_maps'
# match id - 590 ; time spent - 832.5769829750061
# 'total_maps'
# match id - 591 ; time spent - 834.6973247528076
# 'total_maps'
# match id - 592 ; time spent - 836.0798983573914
# 'total_maps'
# match id - 593 ; time spent - 837.4134287834167
# 'total_maps'
# match id - 594 ; time spent - 838.7701270580292
# 'total_maps'
# match id - 595 ; time spent - 840.5806295871735
# 'total_maps'
# match id - 596 ; time spent - 842.0595817565918
# 'total_maps'
# match id - 597 ; time spent - 843.1724824905396
# 'total_maps'
# match id - 598 ; time spent - 846.4975101947784
# 'total_maps'
# match id - 599 ; time spent - 848.6644659042358
# 'NoneType' object is not subscriptable
# match id - 600 ; time spent - 851.9524743556976
# 'total_maps'
# match id - 601 ; time spent - 853.1929738521576
# 'total_maps'
# match id - 602 ; time spent - 854.6433646678925
# 'total_maps'
# match id - 603 ; time spent - 856.148157119751
# 'total_maps'
# match id - 604 ; time spent - 857.5006942749023
# 'total_maps'
# match id - 605 ; time spent - 859.5087876319885
# 'total_maps'
# match id - 606 ; time spent - 860.944638967514
# 'total_maps'
# match id - 607 ; time spent - 862.2214047908783
# 'total_maps'
# match id - 608 ; time spent - 863.6471486091614
# 'total_maps'
# match id - 609 ; time spent - 864.8887660503387
# 'total_maps'
# match id - 610 ; time spent - 866.2198715209961
# 'total_maps'
# match id - 611 ; time spent - 867.7589569091797
# 'total_maps'
# match id - 612 ; time spent - 868.957070350647
# 'total_maps'
# match id - 613 ; time spent - 870.2780785560608
# 'total_maps'
# match id - 614 ; time spent - 871.6371350288391

# %%
TEAM_STAT = 'http://www.hltv.org/stats/teams/matches'


class LastMaps:
    def __init__(self, df, last_maps=10, months=3, start_index=0, finish_index=None):
        self.df = df
        self.TEAM_PAGE = None
        self.MATCH_ID = None
        self.start_index = start_index
        self.finish_index = finish_index
        self.start_date = None
        self.finish_date = None
        self.last_maps = last_maps
        self.months = months

    def add_all_params(self):
        time_start = time.time()
        for date, t1, t2, index in zip(df['date'][self.start_index:self.finish_index],
                                       df['url_team1'][self.start_index:self.finish_index],
                                       df['url_team2'][self.start_index:self.finish_index],
                                       range(len(df['date'][self.start_index:self.finish_index]))):
            self.MATCH_ID = index + self.start_index
            print('match id -', self.MATCH_ID, '; time spent -', time.time() - time_start)
            self.start_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(months=self.months)).strftime("%Y-%m-%d")
            self.finish_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(days=1)).strftime("%Y-%m-%d")
            self.TEAM_PAGE = get_parsed_page(TEAM_STAT +
                                             t1.split('/team')[-1] +
                                             f'?startDate={self.start_date}&endDate={self.finish_date}')
            self.add_last_scores_and_ranks('_team1')
            self.TEAM_PAGE = get_parsed_page(TEAM_STAT +
                                             t2.split('/team')[-1] +
                                             f'?startDate={self.start_date}&endDate={self.finish_date}')
            self.add_last_scores_and_ranks('_team2')
            


    def _get_last_score_(self, team_id, match_id):
        try:
            tmp = self.TEAM_PAGE.find('table', {'class': 'stats-table'}).\
                    find('tbody').find_all('tr')[match_id].find('span', {'class': 'statsDetail'}).text.split(' - ')
            self.df[f'last_maps{match_id + 1}_score{team_id}'][self.MATCH_ID] = tmp[0]
            self.df[f'last_maps{match_id + 1}_opponent_score{team_id}'][self.MATCH_ID] = tmp[1]
        except:
            self.df[f'last_maps{match_id + 1}_score{team_id}'][self.MATCH_ID] = 0
            self.df[f'last_maps{match_id + 1}_opponent_score{team_id}'][self.MATCH_ID] = 0

    def add_last_scores_and_ranks(self, team_id):
        for match_id in range(self.last_maps):
            if f'last_maps{match_id + 1}_score{team_id}' not in self.df:
                self.df[f'last_maps{match_id + 1}_score{team_id}'] = ""
            if f'last_maps{match_id + 1}_opponent_score{team_id}' not in self.df:
                self.df[f'last_maps{match_id + 1}_opponent_score{team_id}'] = ""
            if self.df[f'last_maps{match_id + 1}_score{team_id}'][self.MATCH_ID] == "" or\
                self.df[f'last_maps{match_id + 1}_opponent_score{team_id}'][self.MATCH_ID] == "":
                self._get_last_score_(team_id, match_id)



LastMaps(df).add_all_params()

# %%
PL_STAT = 'https://www.hltv.org'


class PlStatInTeam:
    def __init__(self, df, start_index=0, finish_index=None):
        self.df = df
        self.PL_PAGE = None
        self.MATCH_ID = None
        self.start_index = start_index
        self.finish_index = finish_index
        self.period = None

    def add_all_params(self):
        time_start = time.time()
        for date, index in zip(df['date'][self.start_index:self.finish_index],
                               range(len(df.iloc[self.start_index:self.finish_index]))):
            self.MATCH_ID = index + self.start_index
            print('match id -', self.MATCH_ID, '; time spent -', time.time() - time_start)
            self.period = (datetime.now() - datetime.strptime(date, '%Y-%m-%d')).days
            self.add_5_players(1)
            self.add_5_players(2)
    
    def _get_player_stat_(self, team_id, player):
        print(team_id, player)
        try:
            player_url = (df[f'players_url_{team_id}'][self.MATCH_ID])[player]
        except:
            player_url = (eval(df[f'players_url_{team_id}'][self.MATCH_ID])[player])
        if player_url:
            self.PL_PAGE = get_parsed_page(PL_STAT + player_url + '#tab-teamsBox')  #, proxyDict, proxyAuth)
            tmp = [i.find('div', {'class': 'stat'}).text for i in
                   self.PL_PAGE.find('div', {'class': 'tab-content', 'id': 'teamsBox'}).\
                   find_all('div', {'class': 'highlighted-stat'})]
            tmp = [0 if i == '-' else int(i) for i in tmp]
            self.df[f'player{player + 1}_teams_all_team{team_id}'][self.MATCH_ID] = tmp[0]
            self.df[f'player{player + 1}_days_in_current_team{team_id}'][self.MATCH_ID] = max(tmp[1] - self.period, 0)
            self.df[f'player{player + 1}_days_in_all_team{team_id}'][self.MATCH_ID] = max(tmp[2] - self.period, 0)
        else:
            self.df[f'player{player + 1}_teams_all_team{team_id}'][self.MATCH_ID] = 0
            self.df[f'player{player + 1}_days_in_current_team{team_id}'][self.MATCH_ID] = 0
            self.df[f'player{player + 1}_days_in_all_team{team_id}'][self.MATCH_ID] = 0

    def add_5_players(self, team_id):
        for player in range(5):
            if f'player{player + 1}_teams_all_team{team_id}' not in self.df:
                self.df[f'player{player + 1}_teams_all_team{team_id}'] = ""
            if f'player{player + 1}_days_in_current_team{team_id}' not in self.df:
                self.df[f'player{player + 1}_days_in_current_team{team_id}'] = ""
            if f'player{player + 1}_days_in_all_team{team_id}' not in self.df:
                self.df[f'player{player + 1}_days_in_all_team{team_id}'] = ""
            if self.df[f'player{player + 1}_days_in_current_team{team_id}'][self.MATCH_ID] == "" or\
                self.df[f'player{player + 1}_days_in_all_team{team_id}'][self.MATCH_ID] == "" or\
                self.df[f'player{player + 1}_teams_all_team{team_id}'][self.MATCH_ID] == "":
                self._get_player_stat_(team_id, player)
            

PlStatInTeam(df).add_all_params()

# %%
PL_STAT_ALL = 'https://www.hltv.org/stats/players'

class PlStatAll:
    def __init__(self, df, months=3, start_index=0, finish_index=None):
        self.df = df
        self.PL_PAGE = None
        self.MATCH_ID = None
        self.start_index = start_index
        self.finish_index = finish_index
        self.start_date = None
        self.finish_date = None
        self.months = months
        self.params_1 = ['Total kills', 'Headshot %', 'Total deaths', 'K/D Ratio',
            'Damage / Round', 'Grenade dmg / Round', 'Maps played', 'Rounds played',
            'Kills / round', 'Assists / round', 'Deaths / round',
            'Saved by teammate / round', 'Saved teammates / round', 'Rating 2.0']

    def add_all_params(self):
        time_start = time.time()
        for date, index in zip(df['date'][self.start_index:self.finish_index],
                               range(len(df.iloc[self.start_index:self.finish_index]))):
            self.MATCH_ID = index + self.start_index
            print('match id -', self.MATCH_ID, '; time spent -', time.time() - time_start)
            self.start_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(months=self.months)).strftime("%Y-%m-%d")
            self.finish_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(days=1)).strftime("%Y-%m-%d")
            self.add_5_players_stat(1)
            self.add_5_players_stat(2)
        self.processing_age(self.df)
        self.processing_maps(self.df)
        self.processing_procent(self.df)


    def processing_age(self, df):
        for i in range(len(df)):
            for team_id in range(1, 3):
                for player_id in range(5):
                    if df[f'age_player{player_id + 1}_team{team_id}'][i] == '':
                        df[f'age_player{player_id + 1}_team{team_id}'][i] = 0
                    df[f'age_player{player_id + 1}_team{team_id}'][i] =\
                            re.sub(r'[^\d]', '', str(df[f'age_player{player_id + 1}_team{team_id}'][i]))



    def processing_procent(self, df):
        for i in range(len(df)):
            for team_id in range(1, 3):
                for player_id in range(5):
                    for param in self.params_1:  # Headshot %_player1_team1
                        if str(df[f'{param}_player{player_id + 1}_team{team_id}'][i])[-1] == '%':
                            df[f'{param}_player{player_id + 1}_team{team_id}'][i] =\
                                float(str(df[f'{param}_player{player_id + 1}_team{team_id}'][i])[:-1]) / 100


    def _get_player_stat_(self, team_id, player_id, params_1, params_2):
        def find_row1(stats_row, param):
            for i in stats_row:
                if i.find('span').text == param:
                    return i.find_all('span')[-1].text
            return 0
        
        def find_row2(col_custom, param):
            for i in col_custom:
                if i.find('div', {'class': 'rating-description'}).text == param:
                    tmp = [i.find('div', {'class': 'rating-value'}).text, i.find('div', {'class': 'rating-maps'}).text]
                    return [k if k != '-' else 0 for k in tmp]
            return 0, 0
        
        print(team_id, player_id)
        player_url = (df[f'players_url_{team_id}'][self.MATCH_ID])[player_id]
        if player_url:
            self.PL_PAGE = get_parsed_page(PL_STAT_ALL + player_url.split('/player')[-1] +
                                           f'?startDate={self.start_date}&endDate={self.finish_date}')
            # age
            self.df[f'age_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = self.PL_PAGE.\
                    find('div', {'class': 'playerSummaryStatBox'}).\
                    find('div', {'class': 'summaryPlayerAge'}).text
            # stat params1
            stat1 = self.PL_PAGE.find('div', {'class': 'statistics'}).find_all('div', {'class': 'stats-row'})
            for param in params_1:
                self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = find_row1(stat1, param)
            # stat params2
            stat2 = self.PL_PAGE.find('div', {'class': 'featured-ratings-container'}).\
                    find_all('div', {'class': 'col-custom'})
            for param in params_2:
                (self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID],
                self.df[f'{param}_maps_player{player_id + 1}_team{team_id}'][self.MATCH_ID]) = \
                find_row2(stat2, param)
        else:
            for param in params_1:
                self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = 0
            for param in params_2:
                self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = 0
                self.df[f'{param}_maps_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = 0
            self.df[f'age_player{player_id + 1}_team{team_id}'][self.MATCH_ID] = 0
            

    def add_5_players_stat(self, team_id):
        def check_null_in_line(player_id, params_1, params_2):
            for param in params_1:
                if self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID] == "":
                    return 1
            for param in params_2:
                if self.df[f'{param}_player{player_id + 1}_team{team_id}'][self.MATCH_ID] == "" or \
                    self.df[f'{param}_maps_player{player_id + 1}_team{team_id}'][self.MATCH_ID] == "":
                    return 1
            if self.df[f'age_player{player_id + 1}_team{team_id}'][self.MATCH_ID] == "":
                return 1
            return 0

        for player in range(5):
            for param in self.params_1:
                if f'{param}_player{player + 1}_team{team_id}' not in self.df:
                    self.df[f'{param}_player{player + 1}_team{team_id}'] = ""
            for param in self.params_2:
                if f'{param}_player{player + 1}_team{team_id}' not in self.df:
                    self.df[f'{param}_player{player + 1}_team{team_id}'] = ""
                if f'{param}_maps_player{player + 1}_team{team_id}' not in self.df:
                    self.df[f'{param}_maps_player{player + 1}_team{team_id}'] = ""
            if f'age_player{player + 1}_team{team_id}' not in self.df:
                self.df[f'age_player{player + 1}_team{team_id}'] = ""
            if check_null_in_line(player, self.params_1, self.params_2):
                self._get_player_stat_(team_id, player, self.params_1, self.params_2)



PlStatAll(df).add_all_params()

# %%
MAP_STAT_PR = 'https://www.hltv.org/stats/teams/map/'
id_maps = {
'Dust2': 31,
'Inferno': 33,
'Mirage': 32,
'Nuke': 34,
'Overpass': 40,
'Train': 35,
'Vertigo': 46,
}

def preprocess_allmapsstat(df):
    columns = ['Times played', 'Total rounds played', 'Rounds won', 'Win percent',
                               'Pistol rounds', 'Pistol rounds won', 'Pistol round win percent',
                               'CT round win percent', 'T round win percent']
    columns1 = ['Round win percent after getting first kill',
                                'Round win percent after receiving first death']
    for i in columns:
        for k in list(df.filter(regex=i, axis=1).columns):
            for idx in range(len(df)):
                if str(df[k][idx])[-1] == '%':
                    df[k][idx] = float(str(df[k][idx])[:-1]) / 100
    for i in columns1:
        for k in list(df.filter(regex=i, axis=1).columns):
            for idx in range(len(df)):
                if str(df[k][idx])[-1] == '%':
                    df[k][idx] = float(str(df[k][idx])[:-1]) / 100

class AllMapsStat:
    def __init__(self, df, last_maps=20, months=3, start_index=0, finish_index=None):
        self.df = df
        self.STAT_PAGE = None
        self.idx = None
        self.start_index = start_index
        self.finish_index = finish_index
        self.start_date = None
        self.finish_date = None
        self.last_maps = last_maps
        self.months = months

    def add_all_params(self):
        time_start = time.time()
        for date, index in zip(self.df['date'][self.start_index:self.finish_index],
                       range(len(self.df.iloc[self.start_index:self.finish_index]))):
            self.idx = index + self.start_index
            print('match id -', self.idx, '; time spent -', time.time() - time_start)
            self.start_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(months=self.months)).strftime("%Y-%m-%d")
            self.finish_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(days=1)).strftime("%Y-%m-%d")
            self.add_map_in_df([i for i in id_maps])
        preprocess_allmapsstat(self.df)
    
    
    
    def _get_stat_(self, team_id, params, params1, params2, map_name):
        def _get_params_(team_id, param, table):
            for i in table:
                if i.find('span').text == param:
                    return i.find_all('span')[-1].text
            print('Not find')
            return 0

        def _get_params1_(team_id, param, table):
            for i in table:
                if i.find_all('div')[1].text == param:
                    return i.find('div').text
            print('Not find')
            return 0
    
        def _get_params2_(team_id, param, table):
            score = table.find('td', {'class': 'statsTeamMapResult'}).text
            score = score.split(' - ')
            return score
            
        tmp = self.STAT_PAGE.find_all('div', {'class': 'columns'})
        table = tmp[0].find('div', {'class': 'stats-rows'}).\
                find_all('div', {'class': 'stats-row'})
        for param in params:
            self.df[param + map_name + f'_team{team_id}'][self.idx] = _get_params_(team_id, param, table)
        table = tmp[1].find_all('div', {'class': 'big-padding'})
        for param in params1:
            self.df[param + map_name + f'_team{team_id}'][self.idx] = _get_params1_(team_id, param, table)
        table = self.STAT_PAGE.find('table', {'class': 'stats-table'}).\
                find('tbody').find_all('tr')
        for pos in range(len(params2)):
            param = params2[pos]
            if pos < len(table):
                [self.df[param + map_name + f'_team{team_id}'][self.idx],
                 self.df[param + map_name + '_opponent' + f'_team{team_id}'][self.idx]] = _get_params2_(team_id, param, table[pos])
            else:
                self.df[param + map_name + f'_team{team_id}'][self.idx] = 0
                self.df[param + map_name + '_opponent' + f'_team{team_id}'][self.idx] = 0

    
    def add_map_in_df(self, maps_name):
        def check_null_in_line(team_id, params, params1, params2):
            for param in params:
                if self.df[param + map_name + f'_team{team_id}'][self.idx] == "":
                    return 1
            for param in params1:
                if self.df[param + map_name + f'_team{team_id}'][self.idx] == "":
                    return 1
            for param in params2:
                if self.df[param + map_name + f'_team{team_id}'][self.idx] == "" or\
                        self.df[param + map_name + '_opponent' + f'_team{team_id}'][self.idx] == "":
                    return 1
            return 0
        
        for map_name in maps_name:
            # print(map_name)
            if map_name:
                columns = ['Times played', 'Total rounds played', 'Rounds won', 'Win percent',
                           'Pistol rounds', 'Pistol rounds won', 'Pistol round win percent',
                           'CT round win percent', 'T round win percent']
                columns1 = ['Round win percent after getting first kill',
                            'Round win percent after receiving first death']
                columns2 = [f'map_played{k + 1}'
                            for k in range(self.last_maps)]
                for team_id in range(1, 3):
                    for i in columns:
                        if i + map_name + f'_team{team_id}' not in df:
                            self.df[i + map_name + f'_team{team_id}'] = ""
                    for i in columns1:
                        if i + map_name + f'_team{team_id}' not in df:
                            self.df[i + map_name + f'_team{team_id}'] = ""
                    for i in columns2:
                        if i + map_name + f'_team{team_id}' not in df:
                            self.df[i + map_name + f'_team{team_id}'] = ""
                            self.df[i + map_name + '_opponent' + f'_team{team_id}'] = ""
                # print(self.idx)
                for team_id in range(1, 3):
                    if check_null_in_line(team_id, columns, columns1, columns2):
                        url = MAP_STAT_PR + str(id_maps[map_name]) + '/' +\
                              (df[f'url_team{team_id}'][self.idx]).split('/team/')[-1] +\
                              f'?startDate={self.start_date}&endDate={self.finish_date}'
                        print(url)
                        self.STAT_PAGE = get_parsed_page(url)
                        self._get_stat_(team_id, columns, columns1, columns2, map_name)

cl =  AllMapsStat(df)
cl.add_all_params()

# %%
MAP_STAT_PR = 'https://www.hltv.org/stats/teams/map/'


class MapsStatTeamFull:
    def __init__(self, df, last_maps=20, months=3, start_index=0, finish_index=None):
        self.df = df
        self.dfNew = None
        self.STAT_PAGE = None
        self.MATCH_ID = None
        self.idx = 0
        self.start_index = start_index
        self.finish_index = finish_index
        self.start_date = None
        self.finish_date = None
        self.last_maps = last_maps
        self.months = months

    def add_all_params(self):
        time_start = time.time()
        for maps_url, maps_name, date, score1_maps, score2_maps, picks, index\
            in zip(self.df['maps_url'][self.start_index:self.finish_index],
                       self.df['maps_name'][self.start_index:self.finish_index],
                       self.df['date'][self.start_index:self.finish_index],
                       self.df['score1_maps'][self.start_index:self.finish_index],
                       self.df['score2_maps'][self.start_index:self.finish_index],
                       self.df['picks'][self.start_index:self.finish_index],
                       range(len(self.df.iloc[self.start_index:self.finish_index]))):
            #print(index)
            self.MATCH_ID = index + self.start_index
            print('match id -', self.MATCH_ID, '; time spent -', time.time() - time_start)
            #print(maps_name)
            #print(df['url_team1'][self.MATCH_ID])
            self.start_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(months=self.months)).strftime("%Y-%m-%d")
            self.finish_date = (datetime.strptime(date, '%Y-%m-%d') - relativedelta(days=1)).strftime("%Y-%m-%d")
            if maps_name != 'None':
                self.add_map_in_df(maps_url, maps_name,
                                   score1_maps, score2_maps, picks)
        return self.dfNew
    
    
    
    def _get_stat_(self, team_id, params, params1, params2, score1_map, score2_map, counter, picks):
        def _get_params_(team_id, param, table):
            for i in table:
                if i.find('span').text == param:
                    return i.find_all('span')[-1].text
            print('Not find')
            return 0

        def _get_params1_(team_id, param, table):
            for i in table:
                if i.find_all('div')[1].text == param:
                    return i.find('div').text
            print('Not find')
            return 0
    
        def _get_params2_(team_id, param, table):
            score = table.find('td', {'class': 'statsTeamMapResult'}).text
            score = score.split(' - ')
            return score
            
        tmp = self.STAT_PAGE.find_all('div', {'class': 'columns'})
        table = tmp[0].find('div', {'class': 'stats-rows'}).\
                find_all('div', {'class': 'stats-row'})
        for param in params:
            self.dfNew[param + f'_team{team_id}'][self.idx] = _get_params_(team_id, param, table)
        table = tmp[1].find_all('div', {'class': 'big-padding'})
        for param in params1:
            self.dfNew[param + f'_team{team_id}'][self.idx] = _get_params1_(team_id, param, table)
        table = self.STAT_PAGE.find('table', {'class': 'stats-table'}).\
                find('tbody').find_all('tr')
        for pos in range(len(params2)):
            param = params2[pos]
            if pos < len(table):
                [self.dfNew[param + f'_team{team_id}'][self.idx],
                self.dfNew[param + '_opponent' + f'_team{team_id}'][self.idx]] = _get_params2_(team_id, param, table[pos])
            else:
                self.dfNew[param + f'_team{team_id}'][self.idx] = 0
                self.dfNew[param + '_opponent' + f'_team{team_id}'][self.idx] = 0
        self.dfNew['map_score1'][self.idx] = score1_map
        self.dfNew['map_score2'][self.idx] = score2_map
        if picks and counter < len(picks):
            if picks[counter] == 1:
                self.dfNew['pick1'][self.idx] = 1
                self.dfNew['pick2'][self.idx] = 0
            elif picks[counter] == -1:
                self.dfNew['pick2'][self.idx] = 1
                self.dfNew['pick1'][self.idx] = 0
        else:
            self.dfNew['pick1'][self.idx] = 0
            self.dfNew['pick2'][self.idx] = 0

    
    def add_map_in_df(self, maps_url, maps_name, score1_maps, score2_maps, picks):
        def check_null_in_line(team_id, params, params1, params2):
            for param in params:
                if self.dfNew[param + f'_team{team_id}'][self.idx] == "":
                    return 1
            for param in params1:
                if self.dfNew[param + f'_team{team_id}'][self.idx] == "":
                    return 1
            for param in params2:
                if self.dfNew[param + f'_team{team_id}'][self.idx] == "" or\
                        self.dfNew[param + '_opponent' + f'_team{team_id}'][self.idx] == "":
                    return 1
            for param in ['map_score1', 'map_score2', 'pick1', 'pick2']:
                if self.dfNew[param][self.idx] == "":
                    return 1
            return 0
        
        for map_url, map_name, score1_map, score2_map, counter \
                in zip(maps_url, maps_name, score1_maps, score2_maps, range(len(maps_name))):
            # print(map_name)
            if map_name:
                columns = ['Times played', 'Total rounds played', 'Rounds won', 'Win percent',
                           'Pistol rounds', 'Pistol rounds won', 'Pistol round win percent',
                           'CT round win percent', 'T round win percent']
                columns1 = ['Round win percent after getting first kill',
                            'Round win percent after receiving first death']
                columns2 = [f'current_map_played_{k + 1}'
                            for k in range(self.last_maps)]
                if self.dfNew is None:
                    self.dfNew = self.df.iloc[self.MATCH_ID:self.MATCH_ID + 1].copy()
                    self.idx = 0
                    for team_id in range(1, 3):
                        for i in ['map_score1', 'map_score2', 'pick1', 'pick2']:
                            self.dfNew[i] = ""
                        for i in columns:
                            self.dfNew[i + f'_team{team_id}'] = ""
                        for i in columns1:
                            self.dfNew[i + f'_team{team_id}'] = ""
                        for i in columns2:
                            self.dfNew[i + f'_team{team_id}'] = ""
                            self.dfNew[i + '_opponent' + f'_team{team_id}'] = ""
                else:
                    self.dfNew = self.dfNew.append(self.df.iloc[self.MATCH_ID:self.MATCH_ID + 1].copy(), ignore_index=True)
                    self.idx += 1
                # print(self.idx)
                for team_id in range(1, 3):
                    #if check_null_in_line(team_id, columns, columns1, columns2):
                    url = MAP_STAT_PR + str(id_maps[map_name]) + '/' +\
                          (df[f'url_team{team_id}'][self.MATCH_ID]).split('/team/')[-1] +\
                          f'?startDate={self.start_date}&endDate={self.finish_date}'
                    print(url)
                    self.STAT_PAGE = get_parsed_page(url)
                    self._get_stat_(team_id, columns, columns1, columns2,
                                    score1_map, score2_map, counter, picks)

cl = MapsStatTeamFull(df)
cl.add_all_params()
